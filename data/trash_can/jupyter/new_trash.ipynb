# %%
import pandas as pd

# %%
new_trash=pd.read_excel("./new_trash.xlsx")
new_trash['count']=1
trash_count=new_trash.groupby(['borough','category']).count()[['count']]
trash_count

# %%
trash_count.to_excel('trash_count.xlsx')

# %%
# Out:
#        Unnamed: 0 borough  ...                point         category
# index                      ...
# 1               0     종로구  ...              지하철역 입구            일반쓰레기
# 2               1     종로구  ...              지하철역 입구           재활용쓰레기
# 3               2     종로구  ...              도로(가로)변            일반쓰레기
# 4               3     종로구  ...              도로(가로)변           재활용쓰레기
# 5               4     종로구  ...              도로(가로)변            일반쓰레기
# ...           ...     ...  ...                  ...              ...
# 5371         5370     도봉구  ...          삼환빌라 앞 횡단보도        ⑥ 횡단보도 입구
# 5372         5371     도봉구  ...        창원초등학교 앞 횡단보도        ⑥ 횡단보도 입구
# 5373         5372     도봉구  ...      도봉고등학교 건너편 횡단보도        ⑥ 횡단보도 입구
# 5374         5373     도봉구  ...  신도봉사거리 도봉중학교방향 횡단보도        ⑥ 횡단보도 입구
# 5375         5374     도봉구  ...    창1동 서울가든아파트 버스정류장  ① 정류장(버스, 택시 등)
#
# [5375 rows x 6 columns]
